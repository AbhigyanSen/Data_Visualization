# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Dataset = pd.read_csv("Downloads/marketing_campaign.csv", index_col = 0)

# %%
Dataset.head()
# Out:
#       Year_Birth  Education  Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524        1957          1               0  58138.0        0         0
# 2174        1954          1               0  46344.0        1         1
# 4141        1965          1               1  71613.0        0         0
# 6182        1984          1               1  26646.0        1         0
# 5324        1981          3               3  58293.0        1         0
#
#       Response  Recency  MntWines  MntFruits  ...  NumWebPurchases  \
# ID                                            ...
# 5524         1       58       635         88  ...                8
# 2174         0       38        11          1  ...                1
# 4141         0       26       426         49  ...                8
# 6182         0       26        11          4  ...                2
# 5324         0       94       173         43  ...                5
#
# ...

# %%
plt.figure(figsize = (23, 25))
Pt = sns.heatmap(Dataset.corr(), annot = True, cmap = 'tab20b', vmin = -1, vmax =1)
Pt.set_yticklabels(Pt.get_yticklabels(), rotation = 0, fontsize = 15)
Pt.set_xticklabels(Pt.get_xticklabels(), rotation = 90, fontsize = 15)
plt.show()
